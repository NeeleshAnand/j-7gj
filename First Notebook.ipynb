# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Neelesh Anand** <br>
# Data Analyst

# %% [markdown]
# *I am interested in data science since it offers the satisfaction of getting hidden results. Also it offers good job opportunity.*

# %% [markdown]
# ### Code for adding two variables

# %%
A = 1
B = 2
C = A+B
print (C)
# Out:
# 3

# %% [markdown]
# Horizontal Rule :
# ***
#
# Bulleted List:
# - Bulleted Item 1
# - Bulleted Item 2
#     * Sub item
#
# Numbered List:
# 1. Item 1
# 1. Item 2
# 1. Item 3

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# Hyperlink: <br>
# __[Youtube](http://youtube.com)__
